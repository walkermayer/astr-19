# %% [markdown]
# ## Prompt 1 Journal 2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,1,100)
y = np.exp(x)

# %%
plt.plot(x,y)
plt.xlabel('Time[milliseconds]') 
plt.ylabel('Awesomeness') 
plt.savefig('saveprmt1jrnl2.pdf', format='pdf')
